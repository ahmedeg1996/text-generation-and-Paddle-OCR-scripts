# %%
# !unzip /content/val.zip
# Out:
# Archive:  /content/val.zip
#    creating: val/
#   inflating: val/0.jpg
#   inflating: val/1.jpg
#   inflating: val/10.jpg
#   inflating: val/11.jpg
#   inflating: val/12.jpg
#   inflating: val/13.jpg
#   inflating: val/14.jpg
#   inflating: val/15.jpg
#   inflating: val/16.jpg
#   inflating: val/17.jpg
#   inflating: val/18.jpg
#   inflating: val/19.jpg
#   inflating: val/2.jpg
#   inflating: val/20.jpg
#   inflating: val/21.jpg
#   inflating: val/22.jpg
#   inflating: val/23.jpg
#   inflating: val/24.jpg
#   inflating: val/25.jpg
#   inflating: val/26.jpg
#   inflating: val/27.jpg
#   inflating: val/28.jpg
#   inflating: val/29.jpg
#   inflating: val/3.jpg
#   inflating: val/30.jpg
#   inflating: val/31.jpg
#   inflating: val/32.jpg
#   inflating: val/33.jpg
#   inflating: val/34.jpg
#   inflating: val/35.jpg
#   inflating: val/36.jpg
#   inflating: val/37.jpg
#   inflating: val/38.jpg
#   inflating: val/39.jpg
#   inflating: val/4.jpg
#   inflating: val/40.jpg
# ...

# %%
# !wget -P ./pretrained_models/ https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/arabic_PP-OCRv3_rec_train.tar
# Out:
# --2023-04-27 12:20:18--  https://paddleocr.bj.bcebos.com/PP-OCRv3/multilingual/arabic_PP-OCRv3_rec_train.tar
# Resolving paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)... 103.235.46.61, 2409:8c04:1001:1002:0:ff:b001:368a
# Connecting to paddleocr.bj.bcebos.com (paddleocr.bj.bcebos.com)|103.235.46.61|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209817600 (200M) [application/x-tar]
# Saving to: ‘./pretrained_models/arabic_PP-OCRv3_rec_train.tar’
#
# arabic_PP-OCRv3_rec 100%[===================>] 200.10M  10.4MB/s    in 35s
#
# 2023-04-27 12:20:54 (5.80 MB/s) - ‘./pretrained_models/arabic_PP-OCRv3_rec_train.tar’ saved [209817600/209817600]

# %%
# !rm -rf /content/PaddleOCR/train_data/rec/val

# %%
# !mv /content/PaddleOCR /content/drive/MyDrive/paddleocr

# %%
# !tar -xf /content/pretrained_models/arabic_PP-OCRv3_rec_train.tar

# %%
# !git clone https://github.com/PaddlePaddle/PaddleOCR.git
# Out:
# Cloning into 'PaddleOCR'...
# remote: Enumerating objects: 46287, done.
# remote: Counting objects: 100% (154/154), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 46287 (delta 70), reused 75 (delta 33), pack-reused 46133
# Receiving objects: 100% (46287/46287), 339.28 MiB | 38.27 MiB/s, done.
# Resolving deltas: 100% (32517/32517), done.

# %%
# %cd /content/PaddleOCR
# Out:
# /content/PaddleOCR

# %%
# !pip install -r /content/PaddleOCR/requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.2/608.2 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.5/298.5 kB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 80.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 95.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 MB 13.1 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 97.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 98.5 MB/s eta 0:00:00
# ...

# %%
# !pip install paddlepaddle-gpu==2.3.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.0/394.0 MB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 383.1/383.1 kB 35.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 67.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.0 which is incompatible.
# ...

# %%
import paddle
paddle.utils.run_check()
# Out:
# Running verify PaddlePaddle program ...
# PaddlePaddle works well on 1 GPU.
# PaddlePaddle works well on 1 GPUs.
# PaddlePaddle is installed successfully! Let's start deep learning with PaddlePaddle now.

# %%
# !python3 /content/PaddleOCR/tools/train.py -c /content/PaddleOCR/configs/rec/PP-OCRv3/multi_language/arabic_PP-OCRv3_rec.yml -o Global.pretrained_model=/content/arabic_PP-OCRv3_rec_train/best_accuracy
# Out:
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# GPU evaluation, Global.checkpoints is the weight to be tested
# !python3  tools/eval.py -c /content/PaddleOCR/configs/rec/PP-OCRv3/multi_language/arabic_PP-OCRv3_rec.yml -o Global.checkpoints=/content/drive/MyDrive/model_output/latest.pdparams
# Out:
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# ...

# %%
# %cd /content/PaddleOCR
# Out:
# /content/PaddleOCR

# %%
# GPU evaluation, Global.checkpoints is the weight to be tested
# !python3 tools/eval.py -c /content/PaddleOCR/configs/rec/PP-OCRv3/multi_language/arabic_PP-OCRv3_rec.yml -o Global.checkpoints=/content/drive/MyDrive/model_output/latest.pdparams
# Out:
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# ...

# %%
# Predict Arabic results
# !python3 tools/infer_rec.py -c /content/PaddleOCR/configs/rec/PP-OCRv3/multi_language/arabic_PP-OCRv3_rec.yml -o Global.pretrained_model=/content/drive/MyDrive/model_output/latest.pdparams  Global.infer_img=/content/PaddleOCR/train_data/validation/902.jpg
# Out:
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:121: DeprecationWarning: pkg_resources is deprecated as an API
#   warnings.warn("pkg_resources is deprecated as an API", DeprecationWarning)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.9/dist-packages/pkg_resources/__init__.py:2870: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
# ...

# %%
# !pip install paddleocr
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 KB 19.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 83.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.4/148.4 KB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 KB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached protobuf-3.20.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# ...
#   Created wheel for fire: filename=fire-0.5.0-py2.py3-none-any.whl size=116952 sha256=d6995c5145f51d71b874136c839490ec03b10b6a42ed991b5152eb5dc9ad03ea
#   Stored in directory: /root/.cache/pip/wheels/f7/f1/89/b9ea2bf8f80ec027a88fef1d354b3816b4d3d29530988972f6
# ...

# %%
#Loading the detector and ocr with the previously trained weights
from paddleocr import PaddleOCR
custom_ocr = PaddleOCR()
# Out:
# download https://paddleocr.bj.bcebos.com/PP-OCRv3/chinese/ch_PP-OCRv3_rec_infer.tar to /root/.paddleocr/whl/rec/ch/ch_PP-OCRv3_rec_infer/ch_PP-OCRv3_rec_infer.tar
# 100%|██████████| 11.9M/11.9M [00:13<00:00, 851kiB/s]
# ...

# %%
TextPaddle = custom_ocr.ocr('/content/training/train/1.jpg')
print(TextPaddle)
# Out:
# [2023/04/03 12:18:47] ppocr WARNING: Since the angle classifier is not initialized, the angle classifier will not be uesd during the forward process

# %%
while True:pass
